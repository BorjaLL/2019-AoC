# %% [markdown]
# <a href="https://colab.research.google.com/github/BorjaLL/2019-AoC/blob/master/2020/AOC2020_day_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount gdrive first
import sys,os
#print(sys.path)
#print("Current Working Directory " , os.getcwd())
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks/')

from utils import advent


os.chdir("/content/drive/MyDrive/Colab Notebooks/AOC 2020/")
#os.path.isfile('secret_session_cookie')

advent.setup(2020, 20)
fin = advent.get_input()
# Out:
# [advent] Getting input for year 2020 day 20... done (from disk).

# %%
test_input = """Tile 2311:
..##.#..#.
##..#.....
#...##..#.
####.#...#
##.##.###.
##...#.###
.#.#.#..##
..#....#..
###...#.#.
..###..###

Tile 1951:
#.##...##.
#.####...#
.....#..##
#...######
.##.#....#
.###.#####
###.##.##.
.###....#.
..#.#..#.#
#...##.#..

Tile 1171:
####...##.
#..##.#..#
##.#..#.#.
.###.####.
..###.####
.##....##.
.#...####.
#.##.####.
####..#...
.....##...

Tile 1427:
###.##.#..
.#..#.##..
.#.##.#..#
#.#.#.##.#
....#...##
...##..##.
...#.#####
.#.####.#.
..#..###.#
..##.#..#.

Tile 1489:
##.#.#....
..##...#..
.##..##...
..#...#...
#####...#.
#..#.#.#.#
...#.#.#..
##.#...##.
..##.##.##
###.##.#..

Tile 2473:
#....####.
#..#.##...
#.##..#...
######.#.#
.#...#.#.#
.#########
.###.#..#.
########.#
##...##.#.
..###.#.#.

Tile 2971:
..#.#....#
#...###...
#.#.###...
##.##..#..
.#####..##
.#..####.#
#..#.#..#.
..####.###
..#.#.###.
...#.#.#.#

Tile 2729:
...#.#.#.#
####.#....
..#.#.....
....#..#.#
.##..##.#.
.#.####...
####.#.#..
##.####...
##..#.##..
#.##...##.

Tile 3079:
#.#.#####.
.#..######
..#.......
######....
####.#..#.
.#...#.##.
#.#####.##
..#.###...
..#.......
..#.###...""".split('\n\n')

pieces1=[]
for i in test_input:
  piece=[]
  piece = i.split('\n')
  pieces1.append(piece)

pieces1

pieces=dict()

for i in pieces1:
  pieces [int(i[0][5:len(i[0])-1])]= i[1:]
#pieces

# %%
def find_border(f):
  True
  border1=f[0]

def reverse_str(x):
  return x[::-1]

pieces_borders=dict()

for i in pieces:
  #print (pieces[i])
  #border 1
  border1 = pieces[i][0]
  border2=''
  border3 = pieces[i][len(pieces[i])-1]
  border4 = ''
  for j in pieces[i]:
    border4 += j[0]
  for k in pieces[i]:
    border2 += k[len(k)-1]
  border5=reverse_str(border1)
  border6=reverse_str(border2)
  border7=reverse_str(border3)
  border8=reverse_str(border4)
  pieces_borders[i] = [border1,border2,border3,border4,border5,border6,border7,border8]
borders_match = dict()
def fmatch(vpiece):
  vmatch = 0
  for j,border in enumerate(pieces_borders[vpiece][0:4]):
    nf=1
    for i in pieces_borders:
      if i != vpiece:
        if border in pieces_borders[i]:
          found= pieces_borders[i].index(border)
          borders_match[vpiece, j] = (i,found)
          nf=0
          vmatch += 1
    if nf ==1:
      borders_match[vpiece, j] = 0
  borders_match[vpiece, 'sum'] = vmatch




for vpiece in pieces_borders:
  fmatch(vpiece)
corners=[]
for i in borders_match:
  #print (i[1])
  if i[1] =='sum':
    #print (i)
...#.....#
.###..#.##

Tile 3709:
#####.###.
.###......
#..#....#.
#........#
##..#.#..#
.#.......#
.....#...#
........#.
####..##..
.#..##.###

Tile 2357:
.#..###..#
##..#....#
.....#..##
#...#.....
..........
##...#...#
.#....#..#
##.#....##
....#.#...
#.##.#...#

Tile 3331:
#.#..#.###
#...##.###
....#.#...
..#..#...#
.#.##..#.#
#.....#.#.
..#....#..
#.#.##.#..
#...###...
##..####.#

Tile 1297:
..####.###
#..#....#.
#....#...#
#.........
###.#....#
....#..#..
.##.......
.........#
#..#......
#...#.....""".split('\n\n')

pieces1=[]
for i in test_input:
  piece=[]
  piece = i.split('\n')
  pieces1.append(piece)

pieces1

pieces=dict()

for i in pieces1:
  pieces [int(i[0][5:len(i[0])-1])]= i[1:]
#pieces

# %%
def find_border(f):
  True
  border1=f[0]

def reverse_str(x):
  return x[::-1]

pieces_borders=dict()

for i in pieces:
  #print (pieces[i])
  #border 1
  border1 = pieces[i][0]
  border2=''
  border3 = pieces[i][len(pieces[i])-1]
  border4 = ''
  for j in pieces[i]:
    border4 += j[0]
  for k in pieces[i]:
    border2 += k[len(k)-1]
  border5=reverse_str(border1)
  border6=reverse_str(border2)
  border7=reverse_str(border3)
  border8=reverse_str(border4)
  pieces_borders[i] = [border1,border2,border3,border4,border5,border6,border7,border8]
borders_match = dict()
def fmatch(vpiece):
  vmatch = 0
  for j,border in enumerate(pieces_borders[vpiece][0:4]):
    nf=1
    for i in pieces_borders:
      if i != vpiece:
        if border in pieces_borders[i]:
          found= pieces_borders[i].index(border)
          borders_match[vpiece, j] = (i,found)
          nf=0
          vmatch += 1
    if nf ==1:
      borders_match[vpiece, j] = 0
  borders_match[vpiece, 'sum'] = vmatch




for vpiece in pieces_borders:
  fmatch(vpiece)
corners=[]
for i in borders_match:
  #print (i[1])
  if i[1] =='sum':
    #print (i)
    if borders_match[i]==2:
      corners.append (i[0])
      sol1=1
for i in corners:
  sol1*=i



sol1
# Out:
# 54755174472007

# %% [markdown]
# part 2

# %%
test_input = """Tile 2311:
..##.#..#.
##..#.....
#...##..#.
####.#...#
##.##.###.
##...#.###
.#.#.#..##
..#....#..
###...#.#.
..###..###

Tile 1951:
#.##...##.
#.####...#
.....#..##
#...######
.##.#....#
.###.#####
###.##.##.
.###....#.
..#.#..#.#
#...##.#..

Tile 1171:
####...##.
#..##.#..#
##.#..#.#.
.###.####.
..###.####
.##....##.
.#...####.
#.##.####.
####..#...
.....##...

Tile 1427:
###.##.#..
.#..#.##..
.#.##.#..#
#.#.#.##.#
....#...##
...##..##.
...#.#####
.#.####.#.
..#..###.#
..##.#..#.

Tile 1489:
##.#.#....
..##...#..
.##..##...
..#...#...
#####...#.
#..#.#.#.#
...#.#.#..
##.#...##.
..##.##.##
###.##.#..

Tile 2473:
#....####.
#..#.##...
#.##..#...
######.#.#
.#...#.#.#
.#########
.###.#..#.
########.#
##...##.#.
..###.#.#.

Tile 2971:
..#.#....#
#...###...
#.#.###...
##.##..#..
.#####..##
.#..####.#
#..#.#..#.
..####.###
..#.#.###.
...#.#.#.#

Tile 2729:
...#.#.#.#
####.#....
..#.#.....
....#..#.#
.##..##.#.
.#.####...
####.#.#..
##.####...
##..#.##..
#.##...##.

Tile 3079:
#.#.#####.
.#..######
..#.......
######....
####.#..#.
.#...#.##.
#.#####.##
..#.###...
..#.......
..#.###...""".split('\n\n')

pieces1=[]
for i in test_input:
  piece=[]
  piece = i.split('\n')
  pieces1.append(piece)

pieces1

pieces=dict()

for i in pieces1:
  pieces [int(i[0][5:len(i[0])-1])]= i[1:]
#pieces

# %%
def find_border(f):
  True
  border1=f[0]

def reverse_str(x):
  return x[::-1]

pieces_borders=dict()

for i in pieces:
  #print (pieces[i])
  #border 1
  border1 = pieces[i][0]
  border2=''
  border3 = pieces[i][len(pieces[i])-1]
  border4 = ''
  for j in pieces[i]:
    border4 += j[0]
  for k in pieces[i]:
    border2 += k[len(k)-1]
  border5=reverse_str(border1)
  border6=reverse_str(border2)
  border7=reverse_str(border3)
  border8=reverse_str(border4)
  pieces_borders[i] = [border1,border2,border3,border4,border5,border6,border7,border8]
borders_match = dict()
def fmatch(vpiece):
  vmatch = 0
  for j,border in enumerate(pieces_borders[vpiece][0:4]):
    nf=1
    for i in pieces_borders:
      if i != vpiece:
        if border in pieces_borders[i]:
          found= pieces_borders[i].index(border)
          borders_match[vpiece, j] = (i,found)
          nf=0
          vmatch += 1
    if nf ==1:
      borders_match[vpiece, j] = 0
  borders_match[vpiece, 'sum'] = vmatch




for vpiece in pieces_borders:
  fmatch(vpiece)
corners=[]
for i in borders_match:
  #print (i[1])
  if i[1] =='sum':
    #print (i)
    if borders_match[i]==2:
      corners.append (i[0])
      sol1=1
borders=[]


corners
borders_match
# Out:
# {(1171, 'sum'): 2,
#  (1171, 0): (2473, 3),
#  (1171, 1): (1489, 5),
#  (1171, 2): 0,
#  (1171, 3): 0,
#  (1427, 'sum'): 4,
#  (1427, 0): (1489, 2),
#  (1427, 1): (2473, 2),
#  (1427, 2): (2311, 0),
#  (1427, 3): (2729, 1),
#  (1489, 'sum'): 3,
#  (1489, 0): 0,
#  (1489, 1): (1171, 5),
#  (1489, 2): (1427, 0),
#  (1489, 3): (2971, 1),
#  (1951, 'sum'): 2,
#  (1951, 0): (2729, 2),
#  (1951, 1): (2311, 3),
#  (1951, 2): 0,
#  (1951, 3): 0,
#  (2311, 'sum'): 3,
#  (2311, 0): (1427, 2),
#  (2311, 1): (3079, 7),
#  (2311, 2): 0,
#  (2311, 3): (1951, 1),
#  (2473, 'sum'): 3,
#  (2473, 0): 0,
#  (2473, 1): (3079, 6),
#  (2473, 2): (1427, 1),
#  (2473, 3): (1171, 0),
#  (2729, 'sum'): 3,
#  (2729, 0): (2971, 2),
#  (2729, 1): (1427, 3),
#  (2729, 2): (1951, 0),
#  (2729, 3): 0,
#  (2971, 'sum'): 2,
#  (2971, 0): 0,
#  (2971, 1): (1489, 3),
#  (2971, 2): (2729, 0),
#  (2971, 3): 0,
#  (3079, 'sum'): 2,
#  (3079, 0): 0,
#  (3079, 1): 0,
#  (3079, 2): (2473, 5),
#  (3079, 3): (2311, 5)}
